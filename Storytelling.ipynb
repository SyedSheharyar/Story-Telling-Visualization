# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
death_toll = pd.read_csv("avg_deaths.csv")

# %%
death_toll
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    
plt.show()

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
plt.show()

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right","top","bottom"]:
        ax.spines[location].set_visible(False)
    
plt.show()

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.3)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right","top","bottom"]:
        ax.spines[location].set_visible(False)
        

ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10], death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12], death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
        
plt.show()

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.3)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right","top","bottom"]:
        ax.spines[location].set_visible(False)
        

ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10], death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12], death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
 

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)



plt.show()

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.3)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right","top","bottom"]:
        ax.spines[location].set_visible(False)
        

ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10], death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12], death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
 

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

total = round(death_toll["New_deaths"].sum()/365)

ax1.text(0.5, 3500, f"The Virus Kills {total} People Each Day", size = 18, weight="bold")
ax1.text(0.5, 3150, "Average Number of Daily Deaths Per Day in the US", size = 12)

plt.show()

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.3)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right","top","bottom"]:
        ax.spines[location].set_visible(False)
        

ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10], death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12], death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
 

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

total = round(death_toll["New_deaths"].sum()/365)

ax1.text(0.5, 3500, f"The Virus Kills {total} People Each Day", size = 18, weight="bold")
ax1.text(0.5, 3150, "Average Number of Daily Deaths Per Day in the US", size = 12)


for ax in axes:
    ax.axhline(y = 1600, xmin = 0.5, xmax = 0.8, linewidth = 6, color = "#af0b1e", alpha = 0.3)

plt.show()

# %%
death_toll
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
strt = 0
end = 3
deaths = []

for i in range(4):
    print(death_toll.iloc[strt:end,-1].sum())
    strt = end
    end += 3 
    print("-"*30)
# Out:
# 77
# ------------------------------
# 4077
# ------------------------------
# 2528
# ------------------------------
# 4223
# ------------------------------

# %%
strt = 0
end = 3
deaths = []

for i in range(4):
    total = death_toll.iloc[strt:end,-1].sum()
    deaths.append(total)
    strt = end
    end += 3

# %%
deaths
# Out:
# [77, 4077, 2528, 4223]

# %%
strt = 0
end = 3
csum_deaths = []

for i in range(4):
    total = death_toll.iloc[strt:end,-1].sum()
    csum_deaths.append(total)
    end += 3

# %%
csum_deaths
# Out:
# [77, 4154, 6682, 10905]

# %%
proportions = [d for d in csum_deaths]
proportions
# Out:
# [77, 4154, 6682, 10905]

# %%
t_deaths = death_toll["New_deaths"].sum()

# %%
xmax_vals = []

for d in csum_deaths:
    values = round(0.5 + (d/t_deaths)*0.3,3)
    xmax_vals.append(values)

# %%
xmax_vals
# Out:
# [0.502, 0.614, 0.684, 0.8]

# %%
xmax_vals[0] = 0.503
xmax_vals
# Out:
# [0.503, 0.614, 0.684, 0.8]

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.3)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right","top","bottom"]:
        ax.spines[location].set_visible(False)
        

ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10], death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12], death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
 

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

total = round(death_toll["New_deaths"].sum()/365)

ax1.text(0.5, 3500, f"The Virus Kills {total} People Each Day", size = 18, weight="bold")
ax1.text(0.5, 3150, "Average Number of Daily Deaths Per Day in the US", size = 12)


for ax, my_xmax in zip(axes, xmax_vals):
    ax.axhline(y = 1600, xmin = 0.5, xmax = 0.8, linewidth = 6, color = "#af0b1e", alpha = 0.3)
    ax.axhline(y = 1600, xmin = 0.5, xmax = my_xmax, linewidth = 6, color = "#af0b1e")



plt.show()

# %%
deaths
# Out:
# [77, 4077, 2528, 4223]

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.3)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right","top","bottom"]:
        ax.spines[location].set_visible(False)
        

ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10], death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12], death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
 

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

total = round(death_toll["New_deaths"].sum()/365)

ax1.text(0.5, 3500, f"The Virus Kills {total} People Each Day", size = 18, weight="bold")
ax1.text(0.5, 3150, "Average Number of Daily Deaths Per Day in the US", size = 12)


for ax, my_xmax, death in zip(axes, xmax_vals, deaths):
    ax.axhline(y = 1600, xmin = 0.5, xmax = 0.8, linewidth = 6, color = "#af0b1e", alpha = 0.3)
    ax.axhline(y = 1600, xmin = 0.5, xmax = my_xmax, linewidth = 6, color = "#af0b1e")
    ax.text(7.5, 1850, format(death,","), color = "#af0b1e", weight = "bold")



plt.show()

# %%
fig, [ax1, ax2, ax3, ax4] = plt.subplots(nrows= 4, ncols= 1, figsize = (6,8))

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    ax.plot(death_toll["Month"], death_toll["New_deaths"], color = "#af0b1e", alpha = 0.3)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom = 0, left = 0)
    for location in ["left","right","top","bottom"]:
        ax.spines[location].set_visible(False)
        

ax1.plot(death_toll["Month"][:3], death_toll["New_deaths"][:3], color = "#af0b1e", linewidth = 2.5)
ax2.plot(death_toll["Month"][2:6], death_toll["New_deaths"][2:6], color = "#af0b1e", linewidth = 2.5)
ax3.plot(death_toll["Month"][5:10], death_toll["New_deaths"][5:10], color = "#af0b1e", linewidth = 2.5)
ax4.plot(death_toll["Month"][9:12], death_toll["New_deaths"][9:12], color = "#af0b1e", linewidth = 2.5)
 

ax1.text(1.1, -300, "Jan - Mar", color = "#af0b1e", weight = "bold", rotation = 3)
ax2.text(3.7, 800, "Mar - Jun", color = "#af0b1e", weight = "bold")
ax3.text(7.1, 500, "Jun - Oct", color = "#af0b1e", weight = "bold")
ax4.text(10.5, 600, "Oct - Dec", color = "#af0b1e", weight = "bold", rotation = 45)

total = round(death_toll["New_deaths"].sum()/365)

ax1.text(0.5, 3500, f"The Virus Kills {total} People Each Day", size = 18, weight="bold")
ax1.text(0.5, 3150, "Average Number of Daily Deaths Per Day in the US", size = 12)


for ax, my_xmax, death in zip(axes, xmax_vals, deaths):
    ax.axhline(y = 1600, xmin = 0.5, xmax = 0.8, linewidth = 6, color = "#af0b1e", alpha = 0.3)
    ax.axhline(y = 1600, xmin = 0.5, xmax = my_xmax, linewidth = 6, color = "#af0b1e")
    ax.text(7.5, 1850, format(death,","), color = "#af0b1e", weight = "bold")



plt.savefig("storytelling.jpeg")
plt.show()

# %%
plt.savefig("Storytelling.png")
